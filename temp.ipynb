# %%
from shutil import copyfile
import pandas as pd

# %%
bagls_path = r"F:\hiwi\dataset_bagls\training_224x224"
df = pd.read_csv(r"F:\hiwi\dataset_bagls\bagls_4096.csv")

source_images_paths= [bagls_path + "\\" + x for x in df['images'].to_list()]
source_masks_paths = [bagls_path + "\\" + x for x in df['masks'].to_list()]

target_images_paths = [r"F:\hiwi\dataset_bagls\training_4096\images" + "\\" + x for x in df['images'].to_list()]
target_masks_paths = [r"F:\hiwi\dataset_bagls\training_4096\masks" + "\\" + x for x in df['masks'].to_list()]


for i_th_item in range(len(source_masks_paths)):
    print("copying ", i_th_item, "item...")
    copyfile(source_images_paths[i_th_item], target_images_paths[i_th_item])
    copyfile(source_masks_paths[i_th_item], target_masks_paths[i_th_item])
# Out:
# copying  0 item...
# copying  1 item...
# copying  2 item...
# copying  3 item...
# copying  4 item...
# copying  5 item...
# copying  6 item...
# copying  7 item...
# copying  8 item...
# copying  9 item...
# copying  10 item...
# copying  11 item...
# copying  12 item...
# copying  13 item...
# copying  14 item...
# copying  15 item...
# copying  16 item...
# copying  17 item...
# copying  18 item...
# copying  19 item...
# copying  20 item...
# copying  21 item...
# copying  22 item...
# copying  23 item...
# copying  24 item...
# copying  25 item...
# copying  26 item...
# copying  27 item...
# copying  28 item...
# copying  29 item...
# copying  30 item...
# copying  31 item...
# copying  32 item...
# copying  33 item...
# copying  34 item...
# copying  35 item...
# copying  36 item...
# copying  37 item...
# copying  38 item...
# copying  39 item...
# copying  40 item...
# copying  41 item...
# copying  42 item...
# copying  43 item...
# copying  44 item...
# ...
